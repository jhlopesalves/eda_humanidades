# %% [markdown]
# # Encontro 7: Correlação e Associação

# %% [markdown]
# ## Correlação e associação no Gapminder
#
#
# Considere apenas os dados referentes ao ano de **2007**.
#
# Crie um gráfico de dispersão relacionando:
#
# - `gdpPercap` no eixo \(x\);
# - `lifeExp` no eixo \(y\).
#
# Depois de observar o gráfico, responda:
#
# **Qual parece ser a direção da associação entre PIB per capita e expectativa de vida? A relação parece aproximadamente linear?**

# %%
# Filtre o Gapminder para o ano de 2007 e construa o gráfico de dispersão.

# %% [markdown]
# ### Pearson e Spearman
#
# Agora calcule duas medidas de correlação entre `gdpPercap` e `lifeExp`:
#
# 1. correlação de **Pearson**;
# 2. correlação de **Spearman**.
#
# Compare os dois valores.
#
# **Eles são semelhantes? Se houver diferença, o que essa diferença pode sugerir sobre a forma da relação observada no gráfico?**

# %%
# Calcule as correlações de Pearson e Spearman entre gdpPercap e lifeExp.

# %% [markdown]
# ### Matriz de correlação
#
# Utilizando novamente **todos os países de 2007**, construa uma matriz de correlação de Spearman para:
#
# - `pop`;
# - `lifeExp`;
# - `gdpPercap`.
#
# Depois, represente essa matriz utilizando um **heatmap**.
#
# **Qual é a associação mais forte entre duas variáveis diferentes? Como você interpretaria essa associação em palavras?**

# %%
# Construa a matriz de correlação de Spearman e represente-a com um heatmap.

# %% [markdown]
# ### Uma pequena decisão analítica
#
# Depois de filtrar o conjunto de dados para 2007, todos os valores da coluna `year` são iguais.
#
# **Por que não faria sentido incluir `year` na matriz de correlação desta análise?**

# %% [markdown]
# > Resposta:

# %%
# Use esta célula apenas se quiser verificar sua resposta utilizando Python.

# %% [markdown]
# ### Conclusão
#
# Escreva uma conclusão curta, de aproximadamente **4 a 6 frases**, respondendo à pergunta:
#
# > **O que os dados de 2007 sugerem sobre a relação entre PIB per capita e expectativa de vida entre os países do Gapminder?**
#
# Considere:
#
# - o formato observado no gráfico de dispersão;
# - as correlações de Pearson e Spearman;
# - o resultado da análise de sensibilidade;
# - a diferença entre **associação** e **causalidade**.

# %% [markdown]
# > Resposta:
