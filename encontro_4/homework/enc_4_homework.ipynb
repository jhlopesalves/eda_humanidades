# %% [markdown]
# ## Encontro 4 - Homework: Introdução a NumPy e Pandas

# %% [markdown]
# 1. Importe as bibliotecas NumPy e Pandas com os "aliases" convencionais

# %%
# Importe as bibliotecas

# %% [markdown]
# 2. Execute a célula abaixo para carregar o arquivo `.csv` em um DataFrame.

# %% [markdown]
# Descrição do arquivo:

# %%
url = (
    "https://raw.githubusercontent.com/plotly/datasets/master/"
    "gapminderDataFiveYear.csv"
)

gapminder_df = pd.read_csv(url)

# %% [markdown]
# 3. Dê uma olhada nas colunas e nas 5 primeiras linhas do dataframe.

# %% [markdown]
# 4. Utilize o método apropriado para ter uma 'descrição' dos dados numéricos do dataset: `count`, `mean`, `std`, `25%`, `50%`, `75%` e `max`

# %% [markdown]
# 5.
