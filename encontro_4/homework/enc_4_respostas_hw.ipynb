# %% [markdown]
# <a href="https://colab.research.google.com/github/jhlopesalves/eda_humanidades/blob/main/encontro_4/homework/enc_4_respostas_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Encontro 4 - Homework (Respostas)

# %% [markdown]
# > **Antes de começar:** consulte o notebook do encontro, a documentação oficial e demais materiais de apoio. Tudo o que você precisa para este *homework* está no notebook do encontro, sem exceção.
# >
# > Boa parte deste *homework* pode ser resolvida com a leitura da documentação oficial. Saber navegá-la é uma habilidade tão importante quanto dominar os métodos em si: na prática, ninguém memoriza toda a API (_Application Programming Interface_) -> aprende-se a procurar com eficiência..

# %% [markdown]
# Para cada exercício, tente primeiro identificar **o que** você precisa fazer (filtrar, agrupar, sumarizar, criar uma coluna condicional etc.) e, em seguida, procure o método correspondente na documentação (ou no notebook do encontro - inclusive no meu). Utilize a busca, leia a documentação da função e consulte os exemplos no final da página.
#
# - **NumPy:** [NumPy: the absolute basics for beginners](https://numpy.org/doc/stable/user/absolute_beginners.html)
# - **pandas:** [10 minutes to pandas](https://pandas.pydata.org/docs/user_guide/10min.html#min)

# %% [markdown]
# Também recomendo o `Stack Overflow` para acompanhar discussões sobre Pandas e NumPy, e, na prática, sobre quase tudo que envolve computação:
#
# - [Discussões sobre NumPy](https://stackoverflow.com/questions/tagged/numpy)
# - [Discussões sobre Pandas](https://stackoverflow.com/questions/tagged/pandas)
#
#
# > NO ENTANTO, Não usem o Stack Overflow como **_fonte primária_** para resolver o homework. Priorizem o notebook do encontro e a documentação oficial.
# >
# > O Stack Overflow é um recurso riquíssimo, mas pode ser difícil navegar pelas milhares (talvez milhões?) de discussões por lá. A ideia é que vocês saibam que ele existe e comecem a se familiarizar com discussões reais de programação, sem deixar que a imensidão da plataforma intimide vocês.

# %% [markdown]
# E, claro, o próprio criador da biblioteca pandas ( Wes McKinney) escreveu o livro *Python for Data Analysis* e o disponibilizou na íntegra, gratuitamente, em seu site; não existe fonte com maior autoridade sobre o assunto.
#
# Leia o livro: [Python for Data Analysis](https://wesmckinney.com/book/)

# %% [markdown]
# ## Pois bem, vamos aos exercícios:

# %% [markdown]
# #### 1. Importe as bibliotecas **NumPy** e **Pandas** usando os aliases convencionais da comunidade.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 2. Execute a célula abaixo para carregar o arquivo `.csv` em um DataFrame.

# %%
gapminder_url = (
    "https://raw.githubusercontent.com/jhlopesalves/eda_humanidades/"
    "refs/heads/main/encontro_4/data/gapminderDataFiveYear.csv"
)

gapminder_df = pd.read_csv(gapminder_url)

# %% [markdown]
# ### Sobre o dataset `Gapminder`
#
# O Gapminder é uma fundação sueca independente fundada por Hans Rosling, Ola Rosling e Anna Rosling Rönnlund, dedicada a combater equívocos generalizados sobre o desenvolvimento global por meio de dados públicos e visualizações acessíveis. A organização compila e publica indicadores socioeconômicos provenientes de fontes primárias como o `Banco Mundial`, a `ONU`, a `OMS` e institutos nacionais de estatística.
#
# O arquivo utilizado neste notebook é o recorte clássico popularizado pelo pacote `gapminder` do R (Jennifer Bryan, 2015).
#
# **Descrição das colunas:**
#
# | Coluna | Descrição |
# |---|---|
# | `country` | Nome do país (codificação ASCII, em inglês). |
# | `continent` | Continente de referência (5 categorias: Africa, Americas, Asia, Europe, Oceania). |
# | `year` | Ano de referência da observação (1952–2007, passo de 5 anos). |
# | `pop` | População total estimada no ano. |
# | `lifeExp` | Expectativa de vida ao nascer. |
# | `gdpPercap` | PIB per capita ajustado por paridade de poder de compra, em dólares internacionais constantes; não confundir com PIB nominal em USD atuais. |
#
#
# _Interessante, não é?_

# %% [markdown]
# > **Fonte:** [Gapminder Foundation](https://www.gapminder.org/data/)

# %% [markdown]
# #### 3. Inspecione tamanho e estrutura inicial
#
# Mostre:
#
# 1. o formato do DataFrame com `.shape`;
# 2. os nomes das colunas;
# 3. as 5 primeiras linhas.

# %%
gapminder_df.shape
# Out:
# (1704, 6)

# %%
gapminder_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   str
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   str
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), str(2)
# memory usage: 103.7 KB

# %%
gapminder_df.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %% [markdown]
# ##### 4. Obtenha um resumo estatístico das colunas numéricas do dataset
#
# **Critério**: Mostre `count`, `mean`, `std`, `25%`, `50%`, `75%` e `max` utilizando **UM ÚNICO** método.

# %%
# Resumo estatístico das colunas numéricas
gapminder_df.describe()
# Out:
#              year           pop      lifeExp      gdpPercap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %% [markdown]
# #### 5. Selecione colunas específicas
#
# Selecione as seguintes colunas:
#
# - `country`
# - `continent`
# - `year`
# - `lifeExp`
#
# salve a seleção numa variável chamada `gapminder_small_df`.
#
# Mostre as 5 primeiras linhas desse novo DataFrame.
#
# > hint: `[["coluna1", "coluna2"]]`

# %%
gapminder_small_df = gapminder_df[["country", "continent", "year", "lifeExp"]]
gapminder_small_df.head()
# Out:
#        country continent  year  lifeExp
# 0  Afghanistan      Asia  1952   28.801
# 1  Afghanistan      Asia  1957   30.332
# 2  Afghanistan      Asia  1962   31.997
# 3  Afghanistan      Asia  1967   34.020
# 4  Afghanistan      Asia  1972   36.088

# %% [markdown]
# #### 6. Crie uma máscara booleana
#
# Crie uma variável chamada `mask_2007` que seja `True` para as linhas em que `year` é igual a 2007.
#
# Depois use essa máscara para filtrar o DataFrame.
# Salve a filtragem numa variável chamada `gapminder_2007`
#
# **Critério**:
#
# - `mask_2007` deve retornar valores booleanos;
# - o DataFrame filtrado deve conter apenas observações de 2007.

# %%
mask_2007 = gapminder_df["year"] == 2007
gapminder_2007 = gapminder_df[mask_2007]

# %% [markdown]
# #### 7. Ordene os países em 2007 por expectativa de vida
#
# Use o subconjunto `gapminder_2007` e ordene os países por `lifeExp`, do maior para o menor.
#
# Mostre apenas as colunas:
#
# - `country`
# - `continent`
# - `lifeExp`
# - `gdpPercap`
#
# **Critério**:
#
# - o resultado deve estar filtrado para 2007;
# - as linhas devem estar ordenadas por `lifeExp` em ordem decrescente.

# %%
gapminder_2007[["country", "continent", "lifeExp", "gdpPercap"]].sort_values(
    by="lifeExp", ascending=False
)
# Out:
#                country continent  lifeExp     gdpPercap
# 803              Japan      Asia   82.603  31656.068060
# 671   Hong Kong, China      Asia   82.208  39724.978670
# 695            Iceland    Europe   81.757  36180.789190
# 1487       Switzerland    Europe   81.701  37506.419070
# 71           Australia   Oceania   81.235  34435.367440
# ...                ...       ...      ...           ...
# 887            Lesotho    Africa   42.592   1569.331442
# 1355      Sierra Leone    Africa   42.568    862.540756
# 1691            Zambia    Africa   42.384   1271.211593
# 1043        Mozambique    Africa   42.082    823.685621
# 1463         Swaziland    Africa   39.613   4513.480643
#
# [142 rows x 4 columns]

# %% [markdown]
# #### 8. Para a coluna `lifeExp` (expectativa de vida), calcule separadamente: **média**, **mediana**, **mínimo** e **máximo**.
#
# **Critério**: Guarde cada resultado numa variável e imprima cada métrica usando f-strings.

# %%
media_lifeExp = gapminder_df["lifeExp"].mean()
mediana_lifeExp = gapminder_df["lifeExp"].median()
minimo_lifeExp = gapminder_df["lifeExp"].min()
maximo_lifeExp = gapminder_df["lifeExp"].max()

print(f"Media: {media_lifeExp:.2f}")
print(f"Mediana: {mediana_lifeExp:.2f}")
print(f"Mínimo: {minimo_lifeExp:.2f}")
print(f"Máximo: {maximo_lifeExp:.2f}")
# Out:
# Média: 59.47
# Mediana: 60.71
# Mínimo: 23.60
# Máximo: 82.60

# %% [markdown]
# #### 9. Quantos continentes distintos aparecem na coluna `continent`, e quantas observações há em cada um?

# %%
gapminder_df["continent"].value_counts()
# Out:
# continent
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: count, dtype: int64

# %% [markdown]
# #### 10. Agora apresente a mesma contagem em **proporção** (frequência relativa), em vez de contagem absoluta.

# %%
gapminder_df["continent"].value_counts(normalize=True)
# Out:
# continent
# Africa      0.366197
# Asia        0.232394
# Europe      0.211268
# Americas    0.176056
# Oceania     0.014085
# Name: proportion, dtype: float64

# %% [markdown]
# #### 11. Calcule a média de expectativa de vida (`lifeExp`) por continente.
#
# > psssst... "a média de `lifeExp`, agrupada por `continent`";
# > pense em agrupamentos da 'direita pra esquerda'
# > agrupe por continente, selecione a coluna `lifeExp` e compute a métrica.

# %%
gapminder_df.groupby("continent")["lifeExp"].mean()
# Out:
# continent
# Africa      48.865330
# Americas    64.658737
# Asia        60.064903
# Europe      71.903686
# Oceania     74.326208
# Name: lifeExp, dtype: float64

# %% [markdown]
# #### 12. Faça um subsetting (filtragem) combinando duas condições:
#
# a) matenha apenas as linhas onde o ano (`year`) é 2007;
# b) dentre essas, selecione apenas as colunas `country`, `year`, `lifeExp` e `gdpPercap`.

# %%
gapminder_df.loc[gapminder_df["year"] == 2007, ["country", "year", "lifeExp", "gdpPercap"]]
# Out:
#                  country  year  lifeExp     gdpPercap
# 11           Afghanistan  2007   43.828    974.580338
# 23               Albania  2007   76.423   5937.029526
# 35               Algeria  2007   72.301   6223.367465
# 47                Angola  2007   42.731   4797.231267
# 59             Argentina  2007   75.320  12779.379640
# ...                  ...   ...      ...           ...
# 1655             Vietnam  2007   74.249   2441.576404
# 1667  West Bank and Gaza  2007   73.422   3025.349798
# 1679         Yemen, Rep.  2007   62.698   2280.769906
# 1691              Zambia  2007   42.384   1271.211593
# 1703            Zimbabwe  2007   43.487    469.709298
#
# [142 rows x 4 columns]

# %% [markdown]
# #### 13. Crie uma nova coluna categórica chamada `country_size` segundo a regra:
#
# - população **> 100 milhões** -> `"large"`
# - caso contrário -> `"small"`
#
# Utilize uma função em **NumPy** que aplica uma condição elemento a elemento e retorna um valor para o caso `True` e outro para o `False`.
#
#
#
# > Psssssst: utilize underlines ( `_` ) para digitar números grandes em Python; por exemplo, `1 milhão == 1_000_000`.

# %%
gapminder_df["country_size"] = np.where(gapminder_df["pop"] > 100_000_000, "large", "small")
gapminder_df.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap country_size
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314        small
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030        small
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710        small
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138        small
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106        small

# %% [markdown]
# =)
