# %% [markdown]
# <a href="https://colab.research.google.com/github/jhlopesalves/eda_humanidades/blob/main/encontro_7/homework/enc_7_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Encontro 7: Relações entre variáveis e correlação
#
# Nesta atividade, vamos continuar explorando relações entre variáveis quantitativas por meio de gráficos de dispersão.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns

# %%
arxiv_url = (
    "https://raw.githubusercontent.com/jhlopesalves/"
    "eda_humanidades/refs/heads/main/"
    "encontro_5/data/arxiv_eda_papers.csv"
)

arxiv_df = pd.read_csv(
    arxiv_url,
    dtype={"paper_id": "string"},
)

# %% [markdown]
# > Documentação oficial sobre *scatterplots* (tudo o que você precisa saber está aqui): [Scatterplots - Seaborn](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)

# %% [markdown]
# ### Exercício 1 - Gráfico de dispersão simples
#
# Utilize o DataFrame `arxiv_df` e construa um gráfico de dispersão com:
#
# * `title_n_words` no eixo \(x\);
# * `abstract_n_words` no eixo \(y\).
#
# Use o método `.plot()` do pandas com `kind="scatter"`.
#
# Inclua também:
#
# * um tamanho adequado para a figura;
# * transparência nos pontos com `alpha`;
# * um título para o gráfico.

# %% [markdown]
# ### Exercício 2 - Comparando escala linear e escala logarítmica
#
# Agora, investigue a relação entre:
#
# * `n_authors` no eixo \(x\);
# * `title_n_words` no eixo \(y\).
#
# Construa dois gráficos de dispersão para os mesmos dados:
#
# 1. um com o eixo \(x\) em escala linear;
# 2. outro com o eixo \(x\) em escala logarítmica de base 10.
#
# No segundo gráfico, utilize:
#
# ```python
# ax.set_xscale("log", base=10)
# ```
#
# Utilize Seaborn e Matplotlib para construir e personalizar os gráficos.

# %% [markdown]
# Depois de comparar as duas visualizações, responda brevemente:
#
# 1. O que muda visualmente quando usamos a escala logarítmica no eixo $(x$)?
# 2. Os valores de `n_authors` foram alterados ou apenas a forma como eles são representados no gráfico?
# 3. Em qual dos dois gráficos é mais fácil observar os artigos com números menores de autores? Por quê?

# %% [markdown]
# Respostas Conceituais:
#
# 1.
#
# 2.
#
# 3.
