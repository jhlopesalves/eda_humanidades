# %% [markdown]
# <a href="https://colab.research.google.com/github/jhlopesalves/eda_humanidades/blob/main/encontro_1/homework/enc_1_respostas_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Módulo 1: Primeiros Passos
#
# ### Exercícios por bloco
#
# ### Bloco A - Operadores e variáveis
# - Dados ano de nascimento e morte de 4 autores (Machado (1839-1908), Eça (1845-1900), Guimarães Rosa (1908-1967), Clarice (1920-1977)), calcule a idade de cada um em f-string.
# - Machado publicou um livro em 1881 e outro em 1899.
# Entre o primeiro e o último livro, há 2 intervalos.
# Calcule em variáveis:
#
#     1. Quantos anos se passaram de 1881 até 1899.
#
#     2. Quanto vale cada intervalo, se esse tempo for dividido em 2 partes.
#
# - Se um romance tem 400 páginas e o aluno lê 15 por dia, quantos dias completos de 15 páginas ele lê? Quantas páginas lê no último dia e quantos dias usa ao todo?

# %%
# Anos de nascimento e morte
machado_idade = 1908 - 1839
eca_idade = 1900 - 1845
rosa_idade = 1967 - 1908
clarice_idade = 1977 - 1920

print(f"Idade de Machado: {machado_idade} anos")
print(f"Idade de Eça: {eca_idade} anos")
print(f"Idade de Guimarães Rosa: {rosa_idade} anos")
print(f"Idade de Clarice: {clarice_idade} anos")
# Out:
# Idade de Machado: 69 anos
# Idade de Eça: 55 anos
# Idade de Guimarães Rosa: 59 anos
# Idade de Clarice: 57 anos

# %%
# Intervalo entre publicações
ano_inicio = 1881
ano_fim = 1899

anos_passados = ano_fim - ano_inicio
tamanho_intervalo = anos_passados / 2

print(f"1. Se passaram {anos_passados} anos de 1881 até 1899.")
print(f"2. Cada intervalo vale {tamanho_intervalo} anos.")
# Out:
# 1. Se passaram 18 anos de 1881 até 1899.
# 2. Cada intervalo vale 9.0 anos.

# %%
# Páginas por dia + sobra no último dia
total_paginas = 400
paginas_por_dia = 15

dias_completos = total_paginas // paginas_por_dia
paginas_ultimo_dia = total_paginas % paginas_por_dia
total_dias = (total_paginas + paginas_por_dia - 1) // paginas_por_dia

print(f"O aluno lê {dias_completos} dias completos de 15 páginas.")
print(
    f"No {total_dias}º e último dia, lê as "
    f"{paginas_ultimo_dia} páginas restantes."
)
# Out:
# O aluno lê 26 dias completos de 15 páginas.
# No 27º e último dia, lê as 10 páginas restantes.

# %% [markdown]
# ### Bloco B - Tipos e conversões
# - Dada a int `1899`, salve numa variável e some 10 anos.
# - Aplique `type()` a 5 valores diferentes (incluindo `None`, um float, um bool).
# - **Pergunta conceitual**: por que `"10" + "5"` não dá 15? Explique em duas frases.

# %%
ano = 1899
ano_mais_10 = ano + 10
print(f"1899 + 10 = {ano_mais_10}")
# Out:
# 1899 + 10 = 1909

# %%
print(type(42))
print(type(3.14))
print(type(True))
print(type("texto"))
print(type(None))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# <class 'NoneType'>

# %% [markdown]
# Escreva a resposta para a pergunta conceitual aqui (clique duas vezes para editar a _célula markdown_):
# > Resposta: Porque `"10"` e `"5"` são strings, o operador `+` concatena os dois textos e produz `"105"`. Para obter a soma `15`, os valores precisam ser numéricos, como em `10 + 5`.

# %% [markdown]
# ### Bloco C - Strings
# - Dada a frase `"Words are, in my not-so-humble opinion, our most inexhaustible source of magic"`, aplique e guarde em diferentes variáveis: letras minúsculas, letras maiúsculas e substitua "Words" por "Spells".
# - Construa uma f-string descrevendo um autor com três variáveis: nome, ano de nascimento, obra principal.
# - Dada a palavra `"onomatopeico"`, verifique com `in` se ela contém as letras `"o"`, `"z"` e `"a"`. Três checks.

# %%
# Words are, in my not-so-humble (...)
frase = "Words are, in my not-so-humble opinion, our most inexhaustible source of magic"

frase_minuscula = frase.lower()
frase_maiuscula = frase.upper()
frase_substituida = frase.replace("Words", "Spells")

print("Minúsculas:", frase_minuscula)
print("Maiúsculas:", frase_maiuscula)
print("Substituída:", frase_substituida)
# Out:
# Minúsculas: words are, in my not-so-humble opinion, our most inexhaustible source of magic
# Maiúsculas: WORDS ARE, IN MY NOT-SO-HUMBLE OPINION, OUR MOST INEXHAUSTIBLE SOURCE OF MAGIC
# Substituída: Spells are, in my not-so-humble opinion, our most inexhaustible source of magic

# %%
# f-string: nome, ano, obra
nome = "J.R.R. Tolkien"
ano_nascimento = 1892
obra = "O Senhor dos Anéis"

descricao = f"O autor {nome} nasceu em {ano_nascimento} e é conhecido por escrever {obra}."
print(descricao)
# Out:
# O autor J.R.R. Tolkien nasceu em 1892 e é conhecido por escrever O Senhor dos Anéis.

# %%
# onomatopeico
palavra = "onomatopeico"

tem_o = "o" in palavra
tem_z = "z" in palavra
tem_a = "a" in palavra

print(f"Contém 'o': {tem_o}")
print(f"Contém 'z': {tem_z}")
print(f"Contém 'a': {tem_a}")
# Out:
# Contém 'o': True
# Contém 'z': False
# Contém 'a': True
